# %%
# !pip install git+https://github.com/theislab/scvelo@main
#previous version is broken
# !pip install igraph louvain
# !pip install pybind11 hnswlib

# %%
import pathlib
import scanpy as sc
import scvelo as scv

# %%
current_directory = pathlib.Path.cwd()
module_directory = current_directory.parent.parent
output_path = module_directory / 'output'
scrna_path = module_directory / 'output/integrated_scRNA/heca_normal_scvi_integrated.h5ad'
cell_typist_directory = output_path / 'sc_velo'
if not cell_typist_directory.exists():
    cell_typist_directory.mkdir(parents=True, exist_ok=True)

# %%
scv.set_figure_params()

# %%
adata = sc.read(scrna_path, cache=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 135489 × 4000
#     obs: 'dataset', 'n_genes_by_counts', 'total_counts', 'total_counts_MT', 'pct_counts_MT', 'n_genes', '_scvi_batch', '_scvi_labels', 'leiden'
#     var: 'MT', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'dataset_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_scVI_MDE', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
scv.pl.proportions(adata)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 scv.pl.proportions(adata)
#
# File d:\Coding\comp_bio\endometrial_analysis\scripts\sc_velo\.venv\Lib\site-packages\scvelo\plotting\proportions.py:87, in proportions(adata, groupby, layers, highlight, add_labels_pie, add_labels_bar, fontsize, figsize, dpi, use_raw, show, save)
#      80 explode = [
#      81     0.1 if (layer_key == highlight or layer_key in highlight) else 0
#      82     for layer_key in layers_keys
#      83 ]
#      85 autopct = "%1.0f%%" if add_labels_pie else None
#      86 pie = ax.pie(
# ---> 87     np.mean(counts_layers, axis=1),
#      88     colors=colors,
#      89     explode=explode,
#      90     autopct=autopct,
#      91     shadow=True,
#      92     startangle=45,
#      93 )
#      94 if autopct is not None:
#      95     for pct, color in zip(pie[-1], colors):
#
# ...

# %%
scv.tl.velocity(adata, mode='stochastic')
# Out:
# computing neighbors
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 scv.tl.velocity(adata, mode='stochastic')
#
# File d:\Coding\comp_bio\endometrial_analysis\scripts\sc_velo\.venv\Lib\site-packages\scvelo\tools\velocity.py:326, in velocity(data, vkey, mode, fit_offset, fit_offset2, filter_genes, groups, groupby, groups_for_fit, constrain_ratio, use_raw, use_latent_time, perc, min_r2, min_likelihood, r2_adjusted, use_highly_variable, diff_kinetics, copy, **kwargs)
#     324 adata = data.copy() if copy else data
#     325 if not use_raw and "Ms" not in adata.layers.keys():
# --> 326     moments(adata)
#     328 logg.info("computing velocities", r=True)
#     330 strings_to_categoricals(adata)
#
# ...
